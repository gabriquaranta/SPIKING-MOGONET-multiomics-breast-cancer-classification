# %% [markdown]
# <a href="https://colab.research.google.com/github/gabriquaranta/GU01-bioinspired-spatial-data/blob/main/test_MOGONET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/gabriquaranta/GU01-bioinspired-spatial-data.git
# Out:
# Cloning into 'GU01-bioinspired-spatial-data'...
# remote: Enumerating objects: 119, done.
# remote: Total 119 (delta 0), reused 0 (delta 0), pack-reused 119
# Receiving objects: 100% (119/119), 61.98 MiB | 21.72 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
# Updating files: 100% (83/83), done.

# %%
# %cd GU01-bioinspired-spatial-data/MOGONET/
# Out:
# /content/GU01-bioinspired-spatial-data/MOGONET

# %%
# !python3 main_biomarker.py
# Out:
# /content/GU01-bioinspired-spatial-data/MOGONET/utils.py:43: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:618.)
#   return sparse_tensortype(indices, values, x.size())
# Rank	Feature name
# 1	SOX11|6664
# 2	hsa-mir-205
# 3	GPR37L1
# 4	AMY1A|276
# 5	SLC6A15|55117
# 6	FABP7|2173
# 7	MIR563
# 8	SLC6A14|11254
# 9	hsa-mir-187
# 10	SLC6A2|6530
# 11	FGFBP1|9982
# 12	DSG1|1828
# 13	UGT8|7368
# 14	ANKRD45|339416
# 15	OR1J4
# 16	ATP10B
# 17	PI3|5266
# 18	hsa-mir-452
# 19	hsa-mir-20b
# 20	SERPINB5|5268
# 21	KRTAP3-3
# 22	COL11A2|1302
# 23	hsa-mir-224
# 24	FLJ41941
# 25	ARHGEF4|50649
# 26	SOX10|6663
# 27	TMEM207
# 28	CDH26
# 29	MT1DP
# 30	hsa-mir-204

# %%
# !python3 main_mogonet.py
# Out:
# /content/GU01-bioinspired-spatial-data/MOGONET/utils.py:43: UserWarning: torch.sparse.SparseTensor(indices, values, shape, *, device=) is deprecated.  Please use torch.sparse_coo_tensor(indices, values, shape, dtype=, device=). (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:618.)
#   return sparse_tensortype(indices, values, x.size())
#
# Pretrain GCNs...
#
# Training...
#
# Test: Epoch 0
# Test ACC: 0.175
# Test F1 weighted: 0.066
# Test F1 macro: 0.081
#
#
# Test: Epoch 50
# Test ACC: 0.730
# Test F1 weighted: 0.668
# Test F1 macro: 0.497
#
#
# Test: Epoch 100
# Test ACC: 0.802
# Test F1 weighted: 0.786
# Test F1 macro: 0.706
#
#
# Test: Epoch 150
# Test ACC: 0.814
# Test F1 weighted: 0.799
# Test F1 macro: 0.729
#
#
# Test: Epoch 200
# Test ACC: 0.817
# Test F1 weighted: 0.805
# Test F1 macro: 0.741
#
#
# Test: Epoch 250
# Test ACC: 0.810
# Test F1 weighted: 0.794
# Test F1 macro: 0.724
#
#
# Test: Epoch 300
# Test ACC: 0.787
# Test F1 weighted: 0.754
# ...
